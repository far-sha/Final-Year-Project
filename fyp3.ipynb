# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.read_csv("laptop 2.csv")
df.head()
# Out:
#   Company      Product   TypeName  Inches                              Screen  \
# 0   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Macbook Air  Ultrabook    13.3                            1440x900
# 2      HP       250 G6   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  MacBook Pro  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  MacBook Pro  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#   Touchscreen Screen Resolution                         Cpu  Ram_GB  \
# 0          no         2560x1600        Intel Core i5 2.3GHz       8
# 1          no          1440x900        Intel Core i5 1.8GHz       8
# 2          no         1920x1080  Intel Core i5 7200U 2.5GHz       8
# 3          no         2880x1800        Intel Core i7 2.7GHz      16
# 4          no         2560x1600        Intel Core i5 3.1GHz       8
#
#                 Memory                           Gpu  OpSys  Weight_kg  \
# ...

# %%
def get_id_dpecs(all_data, Inches, Cpu, Ram_GB, Memory, Price_RM):
    all_data1 = all_data.append({'Company' : Company, 'Product' : Product, 'TypeName' : TypeName, 'Inches' : Inches, 'Screen' : Screen, 'Touchscreen' : Touchscreen, 'Screen Resolution':ScreenResolution, 'Cpu': Cpu, 'Ram_GB' : Ram_GB, 'Memory' : Memory, 'Gpu'  :Gpu, 'OpSys' : OpSys, 'Weight_kg' : Weight_kg, 'Price_euros' : Price_euros, 'Price_RM' : Price_RM},ignore_index=True)
    all_data_dummies = pd.get_dummies(all_data1, drop_first=True)
    all_data_dummies = min_max_scaler.fit_transform(all_data_dummies)
    nbrs = NearestNeighbors(n_neighbors=10, algorithm='ball_tree').fit(all_data_dummies)
    distances, indices = nbrs.kneighbors(all_data_dummies)
    
    mask = all_data1.index.isin(indices[-1][1:])
    print(mask,"hello")
    return all_data1.loc[mask]
    
    #for id in indices[-1]:
     #   print(all_data.iloc[id])
    
    get_id_specs(all_data, 13.3, 'Intel Core i5 2.3GHz',8,'128GB SSD',6229.56)
